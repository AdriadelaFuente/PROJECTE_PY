# %%
#Importar biblioteques

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Establim format del seaborn

# %%
gols = pd.read_csv('../datasets/goals.csv')
sns.set(style="darkgrid")

# %%
gols.head(10)
# Out:
#    serial  player_name         club    position  goals  right_foot  left_foot  \
# 0       1      Benzema  Real Madrid     Forward     15          11          1
# 1       2  Lewandowski       Bayern     Forward     13           8          3
# 2       3       Haller         Ajax     Forward     11           3          4
# 3       4        Salah    Liverpool     Forward      8           0          8
# 4       5       Nkunku      Leipzig  Midfielder      7           3          1
# 5       5       Mahrez    Man. City  Midfielder      7           1          4
# 6       7       Mbappé        Paris     Forward      6           6          0
# 7       7        Núñez      Benfica     Forward      6           5          0
# 8       7      Ronaldo  Man. United     Forward      6           5          0
# 9       7      Danjuma   Villarreal  Midfielder      6           3          3
#
#    headers  others  inside_area  outside_areas  penalties  match_played
# ...

# %%
gols.right_foot.head()
# Out:
# 0    11
# 1     8
# 2     3
# 3     0
# 4     3
# Name: right_foot, dtype: int64

# %%
qttClubsApareguts = gols.groupby(['club']).size().plot(kind = "bar", color = "red")

# %%
aux = gols.head()
aux.plot(kind = 'bar', y = ['goals','right_foot','left_foot'], x = 'club')
# Out:
# <AxesSubplot: xlabel='club'>
